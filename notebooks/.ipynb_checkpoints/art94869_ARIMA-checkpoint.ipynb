# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px  # interactive figures
import plotly.graph_objects as go
import seaborn as sns

# %%
import pandas as pd

df = pd.read_csv("../data_raw/date_24_art1_loreal.csv")

df.head()
# Out:
#         DATA  ID_ARTICOL                                            ARTICOL  \
# 0  01-Jan-24      147807  LRP CICAPLAST B5+ BALSAM REPARATOR CALMANT CU ...
# 1  02-Jan-24      147807  LRP CICAPLAST B5+ BALSAM REPARATOR CALMANT CU ...
# 2  03-Jan-24      147807  LRP CICAPLAST B5+ BALSAM REPARATOR CALMANT CU ...
# 3  04-Jan-24      147807  LRP CICAPLAST B5+ BALSAM REPARATOR CALMANT CU ...
# 4  05-Jan-24      147807  LRP CICAPLAST B5+ BALSAM REPARATOR CALMANT CU ...
#
#    CANTITATE  VAL_IESIRE_FARA_TVA  VAL_IESIRE_CU_TVA  VAL_INTRARE_CU_TVA  \
# 0          0                 0.00                0.0                0.00
# 1          0                 0.00                0.0                0.00
# 2         11               647.00              770.0              574.75
# 3         11               647.04              770.0              574.75
# 4         10               588.22              700.0              522.50
#
#    TOTAL_DISCOUNT  RATA_DISCOUNT  ADAOS  STOC_INITIAL  STOC_FINAL  \
# 0             0.0            0.0   0.00           278         278
# 1             0.0            0.0   0.00           278         278
# 2             0.0            0.0  72.25           278         267
# 3             0.0            0.0  72.29           267         376
# 4             0.0            0.0  65.72           376         366
#
#    RUPTURA_STOC
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %% [markdown]
# standard deviation is a way to measure how "spread out" or "different" the values in a group are from the average.
#
# If the standard deviation is small, it means most values are close to the average (not much variation).
# If the standard deviation is large, it means the values are spread out and vary a lot from the average.

# %% [markdown]
# Conversie coloana data din object in datetime

# %%
df['DATA'] = pd.to_datetime(df['DATA'], errors="coerce")
# Out:
# C:\Users\Mara\AppData\Local\Temp\ipykernel_24992\2340964975.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['DATA'] = pd.to_datetime(df['DATA'], errors="coerce")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 734 entries, 0 to 733
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DATA                 734 non-null    datetime64[ns]
#  1   ID_ARTICOL           734 non-null    int64
#  2   ARTICOL              734 non-null    object
#  3   CANTITATE            734 non-null    int64
#  4   VAL_IESIRE_FARA_TVA  734 non-null    float64
#  5   VAL_IESIRE_CU_TVA    734 non-null    float64
#  6   VAL_INTRARE_CU_TVA   734 non-null    float64
#  7   TOTAL_DISCOUNT       734 non-null    float64
#  8   RATA_DISCOUNT        703 non-null    float64
#  9   ADAOS                734 non-null    float64
#  10  STOC_INITIAL         734 non-null    int64
#  11  STOC_FINAL           734 non-null    int64
#  12  RUPTURA_STOC         734 non-null    int64
# dtypes: datetime64[ns](1), float64(6), int64(5), object(1)
# memory usage: 74.7+ KB

# %%
# Sortare logică pentru time series
df = df.sort_values(by=["DATA"]).reset_index(drop=True)

# %%
# reguli de calitate
checks = {}

# 1) vânzare > 0 dar valoare = 0 (suspect)
checks["qty_pos_val_zero"] = df[(df["CANTITATE"] > 0) & (df["VAL_IESIRE_CU_TVA"] == 0)]

# 2) valoare > 0 dar cantitate = 0 (suspect)
checks["val_pos_qty_zero"] = df[(df["VAL_IESIRE_CU_TVA"] > 0) & (df["CANTITATE"] == 0)]

# 3) stoc final negativ (dacă există în dataset)
if "STOC_FINAL" in df.columns:
    checks["stoc_final_negativ"] = df[df["STOC_FINAL"] < 0]

# 4) discount > 0 dar rata_discount = 0 (suspect)
if "TOTAL_DISCOUNT" in df.columns and "RATA_DISCOUNT" in df.columns:
    checks["disc_pos_rata_zero"] = df[(df["TOTAL_DISCOUNT"] > 0) & (df["RATA_DISCOUNT"] == 0)]

# 5) 
checks["stockout_start"] = df[(df["STOC_INITIAL"] == 0) & (df["CANTITATE"] == 0)]
checks["no_sales_but_in_stock"] = df[(df["STOC_INITIAL"] > 0) & (df["CANTITATE"] == 0)]

{k: v.shape[0] for k, v in checks.items()}
# Out:
# {'qty_pos_val_zero': 0,
#  'val_pos_qty_zero': 0,
#  'stoc_final_negativ': 0,
#  'disc_pos_rata_zero': 0,
#  'stockout_start': 0,
#  'no_sales_but_in_stock': 16}

# %%
cols = ["CANTITATE", "STOC_INITIAL", "STOC_FINAL", "VAL_IESIRE_FARA_TVA"]

(df[cols] < 0).sum()
# Out:
# CANTITATE              0
# STOC_INITIAL           0
# STOC_FINAL             0
# VAL_IESIRE_FARA_TVA    0
# dtype: int64

# %%
# df = df.set_index('DATA')

# %%
# df

# %% [markdown]
# Pentru evitarea redundanței informaționale, variabilele puternic corelate vor fi filtrate.  ( gen val iesire cu fara tva, total discount - rata discount )

# %%
df_feat = df.drop(columns=[ "STOC_FINAL", "RUPTURA_STOC", "VAL_IESIRE_CU_TVA", "RATA_DISCOUNT"])

df_feat
# Out:
#           DATA  ID_ARTICOL                                            ARTICOL  \
# 0   2024-01-01      147807  LRP CICAPLAST B5+ BALSAM REPARATOR CALMANT CU ...
# 1   2024-01-02      147807  LRP CICAPLAST B5+ BALSAM REPARATOR CALMANT CU ...
# 2   2024-01-03      147807  LRP CICAPLAST B5+ BALSAM REPARATOR CALMANT CU ...
# 3   2024-01-04      147807  LRP CICAPLAST B5+ BALSAM REPARATOR CALMANT CU ...
# 4   2024-01-05      147807  LRP CICAPLAST B5+ BALSAM REPARATOR CALMANT CU ...
# ..         ...         ...                                                ...
# 729 2025-12-30      147807  LRP CICAPLAST B5+ BALSAM REPARATOR CALMANT CU ...
# 730 2025-12-31      147807  LRP CICAPLAST B5+ BALSAM REPARATOR CALMANT CU ...
# 731 2026-01-01      147807  LRP CICAPLAST B5+ BALSAM REPARATOR CALMANT CU ...
# 732 2026-01-02      147807  LRP CICAPLAST B5+ BALSAM REPARATOR CALMANT CU ...
# 733 2026-01-03      147807  LRP CICAPLAST B5+ BALSAM REPARATOR CALMANT CU ...
#
#      CANTITATE  VAL_IESIRE_FARA_TVA  VAL_INTRARE_CU_TVA  TOTAL_DISCOUNT  \
# 0            0                 0.00                0.00             0.0
# 1            0                 0.00                0.00             0.0
# 2           11               647.00              574.75             0.0
# 3           11               647.04              574.75             0.0
# 4           10               588.22              522.50             0.0
# ..         ...                  ...                 ...             ...
# 729         12               719.02              627.00             0.0
# 730          7               419.44              365.75             0.0
# 731          0                 0.00                0.00             0.0
# 732          0                 0.00                0.00             0.0
# 733         13               778.96              679.25             0.0
#
#      ADAOS  STOC_INITIAL
# 0     0.00           278
# 1     0.00           278
# 2    72.25           278
# 3    72.29           267
# 4    65.72           376
# ..     ...           ...
# 729  92.02          1441
# 730  53.69          1429
# 731   0.00          1422
# 732   0.00          1422
# 733  99.71          1422
#
# [734 rows x 9 columns]

# %%
df_feat["DOW"] = df_feat["DATA"].dt.dayofweek          # 0..6
df_feat["ESTE_WEEKEND"] = (df_feat["DOW"] >= 5).astype(int)

# dacă ai deja LUNA ca yyyy-mm, păstreaz-o ca perioadă (opțional)
# df_feat["YYYY_MM"] = df_feat["DATA"].dt.to_period("M").astype(str)

# opțional: zi din lună (uneori surprinde patternuri de început/sfârșit)
df_feat["ZI_DIN_LUNA"] = df_feat["DATA"].dt.day

df_feat
# Out:
#           DATA  ID_ARTICOL                                            ARTICOL  \
# 0   2024-01-01      147807  LRP CICAPLAST B5+ BALSAM REPARATOR CALMANT CU ...
# 1   2024-01-02      147807  LRP CICAPLAST B5+ BALSAM REPARATOR CALMANT CU ...
# 2   2024-01-03      147807  LRP CICAPLAST B5+ BALSAM REPARATOR CALMANT CU ...
# 3   2024-01-04      147807  LRP CICAPLAST B5+ BALSAM REPARATOR CALMANT CU ...
# 4   2024-01-05      147807  LRP CICAPLAST B5+ BALSAM REPARATOR CALMANT CU ...
# ..         ...         ...                                                ...
# 729 2025-12-30      147807  LRP CICAPLAST B5+ BALSAM REPARATOR CALMANT CU ...
# 730 2025-12-31      147807  LRP CICAPLAST B5+ BALSAM REPARATOR CALMANT CU ...
# 731 2026-01-01      147807  LRP CICAPLAST B5+ BALSAM REPARATOR CALMANT CU ...
# 732 2026-01-02      147807  LRP CICAPLAST B5+ BALSAM REPARATOR CALMANT CU ...
# 733 2026-01-03      147807  LRP CICAPLAST B5+ BALSAM REPARATOR CALMANT CU ...
#
#      CANTITATE  VAL_IESIRE_FARA_TVA  VAL_INTRARE_CU_TVA  TOTAL_DISCOUNT  \
# 0            0                 0.00                0.00             0.0
# 1            0                 0.00                0.00             0.0
# 2           11               647.00              574.75             0.0
# 3           11               647.04              574.75             0.0
# 4           10               588.22              522.50             0.0
# ..         ...                  ...                 ...             ...
# 729         12               719.02              627.00             0.0
# 730          7               419.44              365.75             0.0
# 731          0                 0.00                0.00             0.0
# 732          0                 0.00                0.00             0.0
# 733         13               778.96              679.25             0.0
#
#      ADAOS  STOC_INITIAL  DOW  ESTE_WEEKEND  ZI_DIN_LUNA
# 0     0.00           278    0             0            1
# 1     0.00           278    1             0            2
# 2    72.25           278    2             0            3
# 3    72.29           267    3             0            4
# 4    65.72           376    4             0            5
# ..     ...           ...  ...           ...          ...
# 729  92.02          1441    1             0           30
# 730  53.69          1429    2             0           31
# 731   0.00          1422    3             0            1
# 732   0.00          1422    4             0            2
# 733  99.71          1422    5             1            3
#
# [734 rows x 12 columns]

# %%
fig = px.line(df, x='DATA', y='CANTITATE', title='Time Series with Range Slider and Selectors')

fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1m", step="month", stepmode="backward"),
            dict(count=6, label="6m", step="month", stepmode="backward"),
            # dict(count=1, label="YTD", step="year", stepmode="todate"),
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(step="all")
        ])
    )
)

fig.update_layout(width=1100, height=500)
fig.show()

# %% [markdown]
# ## ARIMA

# %%
# df_art = df.set_index("DATA")["CANTITATE"].asfreq("D")
# ARIMA works with series, not dataframes
df_art = (
    df
    .set_index("DATA")["CANTITATE"]
    .astype(float)
    .sort_index()
)

# %%
df_art
# Out:
# DATA
# 2024-01-01     0.0
# 2024-01-02     0.0
# 2024-01-03    11.0
# 2024-01-04    11.0
# 2024-01-05    10.0
#               ...
# 2025-12-30    12.0
# 2025-12-31     7.0
# 2026-01-01     0.0
# 2026-01-02     0.0
# 2026-01-03    13.0
# Name: CANTITATE, Length: 734, dtype: float64

# %%
df_art.map(type).value_counts().head(10)
# Out:
# CANTITATE
# <class 'float'>    734
# Name: count, dtype: int64

# %%
type(df_art)
df_art.name
df_art.index.name
df_art.dtype
df_art.head()
# Out:
# DATA
# 2024-01-01     0.0
# 2024-01-02     0.0
# 2024-01-03    11.0
# 2024-01-04    11.0
# 2024-01-05    10.0
# Name: CANTITATE, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
# Out:
# C:\Users\Mara\AppData\Roaming\Python\Python313\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning:
#
# In the future `np.object` will be defined as the corresponding NumPy scalar.

# %%
# pip install tensorflow

# %%
split_ratio = 0.8
n = len(df_art)
split_idx = int(n * split_ratio)

split_idx
# Out:
# 587

# %%
train = df_art.iloc[:split_idx]
test  = df_art.iloc[split_idx:]

# %%
# import libraries
from statsmodels.tsa.stattools import adfuller

# ADF test
result = adfuller(train.dropna())
print('ADF Statistic:', result[0])
print('p-value:', result[1])

# if p-value > 0.05, the series is non-stationary and needs differencing
if result[1] > 0.05:
    print("needs differencing")
else:
    print("time series is stationary")
# Out:
# ADF Statistic: -3.7874346810000405
# p-value: 0.003038522956429229
# time series is stationary

# %%
from pmdarima import auto_arima

model_auto = auto_arima(
    train,
    seasonal=False,
    d=0,
    stepwise=True,
    suppress_warnings=True,
    trace=True
)

model_auto.order
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=3750.792, Time=0.19 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4858.772, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=3836.232, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=4417.711, Time=0.06 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=3745.149, Time=0.14 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=4187.805, Time=0.11 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=3750.083, Time=0.08 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=3735.923, Time=0.20 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=4067.301, Time=0.13 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=3737.408, Time=0.33 sec
#  ARIMA(1,0,4)(0,0,0)[0]             : AIC=3736.713, Time=0.18 sec
#  ARIMA(0,0,4)(0,0,0)[0]             : AIC=4017.534, Time=0.19 sec
#  ARIMA(2,0,4)(0,0,0)[0]             : AIC=3733.086, Time=0.38 sec
#  ARIMA(3,0,4)(0,0,0)[0]             : AIC=3729.236, Time=0.70 sec
#  ARIMA(3,0,3)(0,0,0)[0]             : AIC=3743.902, Time=0.29 sec
#  ARIMA(4,0,4)(0,0,0)[0]             : AIC=3730.099, Time=0.92 sec
#  ARIMA(3,0,5)(0,0,0)[0]             : AIC=3729.255, Time=0.87 sec
#  ARIMA(2,0,5)(0,0,0)[0]             : AIC=3734.099, Time=0.42 sec
#  ARIMA(4,0,3)(0,0,0)[0]             : AIC=3729.140, Time=0.62 sec
#  ARIMA(4,0,2)(0,0,0)[0]             : AIC=3729.154, Time=0.60 sec
#  ARIMA(5,0,3)(0,0,0)[0]             : AIC=3729.555, Time=0.73 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=3744.232, Time=0.44 sec
#  ARIMA(5,0,2)(0,0,0)[0]             : AIC=3729.542, Time=0.56 sec
#  ARIMA(5,0,4)(0,0,0)[0]             : AIC=3721.631, Time=0.71 sec
#  ARIMA(5,0,5)(0,0,0)[0]             : AIC=3723.245, Time=1.01 sec
#  ARIMA(4,0,5)(0,0,0)[0]             : AIC=3733.236, Time=0.51 sec
#  ARIMA(5,0,4)(0,0,0)[0] intercept   : AIC=3706.961, Time=1.23 sec
#  ARIMA(4,0,4)(0,0,0)[0] intercept   : AIC=3720.552, Time=0.98 sec
#  ARIMA(5,0,3)(0,0,0)[0] intercept   : AIC=3719.994, Time=1.12 sec
#  ARIMA(5,0,5)(0,0,0)[0] intercept   : AIC=3711.946, Time=1.30 sec
#  ARIMA(4,0,3)(0,0,0)[0] intercept   : AIC=3719.599, Time=0.98 sec
#  ARIMA(4,0,5)(0,0,0)[0] intercept   : AIC=3723.234, Time=0.70 sec
#
# Best model:  ARIMA(5,0,4)(0,0,0)[0] intercept
# Total fit time: 16.722 seconds
# (5, 0, 4)

# %%
from statsmodels.tsa.arima.model import ARIMA

arima = ARIMA(train, order=(5, 0, 4))
arima_fit = arima.fit()
# Out:
# C:\Users\Mara\AppData\Roaming\Python\Python313\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency D will be used.
#
# C:\Users\Mara\AppData\Roaming\Python\Python313\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency D will be used.
#
# C:\Users\Mara\AppData\Roaming\Python\Python313\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency D will be used.
#
# C:\Users\Mara\AppData\Roaming\Python\Python313\site-packages\statsmodels\base\model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals

# %%
pred_arima = arima_fit.forecast(steps=len(test))

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

mae = mean_absolute_error(test, pred_arima)

mse = mean_squared_error(test, pred_arima)
rmse = np.sqrt(mse)

r2 = r2_score(test, pred_arima)


mae = float(mae)
rmse = float(rmse)


mae, rmse, r2
# Out:
# (7.0267202407421125, 11.159382520972338, 0.0009644838365682196)

# %%
import numpy as np

r = np.corrcoef(test, pred_arima)[0, 1]
float(r)
# arata daca modelul urmareste trandul, nu cat de exact prezice
# Out:
# 0.0426334787607541

# %%
import pandas as pd
import plotly.express as px

df_plot_arima = pd.DataFrame({
    "DATA": test.index,
    "Actual": test.values,
    "Predicted": pred_arima
})

df_long_arima = df_plot_arima.melt(
    id_vars="DATA",
    value_vars=["Actual", "Predicted"],
    var_name="Serie",
    value_name="Cantitate"
)

fig = px.line(
    df_long_arima,
    x="DATA",
    y="Cantitate",
    color="Serie",
    title="ARIMA – Actual vs Predicted"
)

fig.update_layout(
    xaxis_title="Data",
    yaxis_title="Cantitate vândută",
    hovermode="x unified",
    legend_title_text=""
)

fig.update_xaxes(rangeslider_visible=True)

fig.show()
