# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px  # interactive figures
import plotly.graph_objects as go
import seaborn as sns

# %%
import pandas as pd

df = pd.read_csv("../data_raw/date_24_art_loreal_20%.csv")

df = df[df["ID_ARTICOL"] == 94869]

df.head()
# Out:
#          DATA  ID_ARTICOL                                            ARTICOL  \
# 4   01-Jan-24       94869  CERAVE LOTIUNE HIDRATANTA PENTRU FATA SI CORP ...
# 14  02-Jan-24       94869  CERAVE LOTIUNE HIDRATANTA PENTRU FATA SI CORP ...
# 38  03-Jan-24       94869  CERAVE LOTIUNE HIDRATANTA PENTRU FATA SI CORP ...
# 49  04-Jan-24       94869  CERAVE LOTIUNE HIDRATANTA PENTRU FATA SI CORP ...
# 52  05-Jan-24       94869  CERAVE LOTIUNE HIDRATANTA PENTRU FATA SI CORP ...
#
#     CANTITATE  VAL_IESIRE_FARA_TVA  VAL_IESIRE_CU_TVA  VAL_INTRARE_FARA_TVA  \
# 4           0                 0.00                0.0                  0.00
# 14          0                 0.00                0.0                  0.00
# 38         10               571.46              680.0                508.30
# 49          4               228.57              272.0                203.32
# 52         12               685.69              816.0                609.96
#
#     TOTAL_DISCOUNT  RATA_DISCOUNT  ADAOS  STOC_INITIAL  STOC_FINAL  \
# 4              0.0            0.0   0.00           168         168
# 14             0.0            0.0   0.00           168         168
# 38             0.0            0.0  63.16           168         158
# 49             0.0            0.0  25.25           158         214
# 52             0.0            0.0  75.73           214         202
#
#     RUPTURA_STOC
# 4              0
# 14             0
# 38             0
# 49             0
# 52             0

# %% [markdown]
# standard deviation is a way to measure how "spread out" or "different" the values in a group are from the average.
#
# If the standard deviation is small, it means most values are close to the average (not much variation).
# If the standard deviation is large, it means the values are spread out and vary a lot from the average.

# %% [markdown]
# Conversie coloana data din object in datetime

# %%
df['DATA'] = pd.to_datetime(df['DATA'], errors="coerce")
# Out:
# C:\Users\Mara\AppData\Local\Temp\ipykernel_3488\2340964975.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['DATA'] = pd.to_datetime(df['DATA'], errors="coerce")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 733 entries, 4 to 9992
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   DATA                  733 non-null    datetime64[ns]
#  1   ID_ARTICOL            733 non-null    int64
#  2   ARTICOL               733 non-null    object
#  3   CANTITATE             733 non-null    int64
#  4   VAL_IESIRE_FARA_TVA   733 non-null    float64
#  5   VAL_IESIRE_CU_TVA     733 non-null    float64
#  6   VAL_INTRARE_FARA_TVA  733 non-null    float64
#  7   TOTAL_DISCOUNT        733 non-null    float64
#  8   RATA_DISCOUNT         706 non-null    float64
#  9   ADAOS                 733 non-null    float64
#  10  STOC_INITIAL          733 non-null    int64
#  11  STOC_FINAL            733 non-null    int64
#  12  RUPTURA_STOC          733 non-null    int64
# dtypes: datetime64[ns](1), float64(6), int64(5), object(1)
# memory usage: 80.2+ KB

# %%
# Sortare logică pentru time series
df = df.sort_values(by=["DATA"]).reset_index(drop=True)

# %%
# reguli de calitate
checks = {}

# 1) vânzare > 0 dar valoare = 0 (suspect)
checks["qty_pos_val_zero"] = df[(df["CANTITATE"] > 0) & (df["VAL_IESIRE_CU_TVA"] == 0)]

# 2) valoare > 0 dar cantitate = 0 (suspect)
checks["val_pos_qty_zero"] = df[(df["VAL_IESIRE_CU_TVA"] > 0) & (df["CANTITATE"] == 0)]

# 3) stoc final negativ (dacă există în dataset)
if "STOC_FINAL" in df.columns:
    checks["stoc_final_negativ"] = df[df["STOC_FINAL"] < 0]

# 4) discount > 0 dar rata_discount = 0 (suspect)
if "TOTAL_DISCOUNT" in df.columns and "RATA_DISCOUNT" in df.columns:
    checks["disc_pos_rata_zero"] = df[(df["TOTAL_DISCOUNT"] > 0) & (df["RATA_DISCOUNT"] == 0)]

# 5) 
checks["stockout_start"] = df[(df["STOC_INITIAL"] == 0) & (df["CANTITATE"] == 0)]
checks["no_sales_but_in_stock"] = df[(df["STOC_INITIAL"] > 0) & (df["CANTITATE"] == 0)]

{k: v.shape[0] for k, v in checks.items()}
# Out:
# {'qty_pos_val_zero': 1,
#  'val_pos_qty_zero': 0,
#  'stoc_final_negativ': 0,
#  'disc_pos_rata_zero': 1,
#  'stockout_start': 1,
#  'no_sales_but_in_stock': 24}

# %%
cols = ["CANTITATE", "STOC_INITIAL", "STOC_FINAL", "VAL_IESIRE_FARA_TVA"]

(df[cols] < 0).sum()
# Out:
# CANTITATE              0
# STOC_INITIAL           0
# STOC_FINAL             0
# VAL_IESIRE_FARA_TVA    0
# dtype: int64

# %%
# df = df.set_index('DATA')

# %%
# df

# %% [markdown]
# Pentru evitarea redundanței informaționale, variabilele puternic corelate vor fi filtrate.  ( gen val iesire cu fara tva, total discount - rata discount )

# %%
df_feat = df.drop(columns=[ "STOC_FINAL", "RUPTURA_STOC", "VAL_IESIRE_CU_TVA", "RATA_DISCOUNT"])

df_feat
# Out:
#           DATA  ID_ARTICOL                                            ARTICOL  \
# 0   2024-01-01       94869  CERAVE LOTIUNE HIDRATANTA PENTRU FATA SI CORP ...
# 1   2024-01-02       94869  CERAVE LOTIUNE HIDRATANTA PENTRU FATA SI CORP ...
# 2   2024-01-03       94869  CERAVE LOTIUNE HIDRATANTA PENTRU FATA SI CORP ...
# 3   2024-01-04       94869  CERAVE LOTIUNE HIDRATANTA PENTRU FATA SI CORP ...
# 4   2024-01-05       94869  CERAVE LOTIUNE HIDRATANTA PENTRU FATA SI CORP ...
# ..         ...         ...                                                ...
# 728 2025-12-31       94869  CERAVE LOTIUNE HIDRATANTA PENTRU FATA SI CORP ...
# 729 2026-01-01       94869  CERAVE LOTIUNE HIDRATANTA PENTRU FATA SI CORP ...
# 730 2026-01-02       94869  CERAVE LOTIUNE HIDRATANTA PENTRU FATA SI CORP ...
# 731 2026-01-03       94869  CERAVE LOTIUNE HIDRATANTA PENTRU FATA SI CORP ...
# 732 2026-01-04       94869  CERAVE LOTIUNE HIDRATANTA PENTRU FATA SI CORP ...
#
#      CANTITATE  VAL_IESIRE_FARA_TVA  VAL_INTRARE_FARA_TVA  TOTAL_DISCOUNT  \
# 0            0                 0.00                  0.00             0.0
# 1            0                 0.00                  0.00             0.0
# 2           10               571.46                508.30             0.0
# 3            4               228.57                203.32             0.0
# 4           12               685.69                609.96             0.0
# ..         ...                  ...                   ...             ...
# 728          1                61.99                 54.15             0.0
# 729          0                 0.00                  0.00             0.0
# 730          0                 0.00                  0.00             0.0
# 731          6               371.88                324.90             0.0
# 732          6               371.91                324.90             0.0
#
#      ADAOS  STOC_INITIAL
# 0     0.00           168
# 1     0.00           168
# 2    63.16           168
# 3    25.25           158
# 4    75.73           214
# ..     ...           ...
# 728   7.84           243
# 729   0.00           242
# 730   0.00           242
# 731  46.98           242
# 732  47.01           236
#
# [733 rows x 9 columns]

# %%
df_feat["DOW"] = df_feat["DATA"].dt.dayofweek          # 0..6
df_feat["ESTE_WEEKEND"] = (df_feat["DOW"] >= 5).astype(int)

# dacă ai deja LUNA ca yyyy-mm, păstreaz-o ca perioadă (opțional)
# df_feat["YYYY_MM"] = df_feat["DATA"].dt.to_period("M").astype(str)

# opțional: zi din lună (uneori surprinde patternuri de început/sfârșit)
df_feat["ZI_DIN_LUNA"] = df_feat["DATA"].dt.day

df_feat
# Out:
#           DATA  ID_ARTICOL                                            ARTICOL  \
# 0   2024-01-01       94869  CERAVE LOTIUNE HIDRATANTA PENTRU FATA SI CORP ...
# 1   2024-01-02       94869  CERAVE LOTIUNE HIDRATANTA PENTRU FATA SI CORP ...
# 2   2024-01-03       94869  CERAVE LOTIUNE HIDRATANTA PENTRU FATA SI CORP ...
# 3   2024-01-04       94869  CERAVE LOTIUNE HIDRATANTA PENTRU FATA SI CORP ...
# 4   2024-01-05       94869  CERAVE LOTIUNE HIDRATANTA PENTRU FATA SI CORP ...
# ..         ...         ...                                                ...
# 728 2025-12-31       94869  CERAVE LOTIUNE HIDRATANTA PENTRU FATA SI CORP ...
# 729 2026-01-01       94869  CERAVE LOTIUNE HIDRATANTA PENTRU FATA SI CORP ...
# 730 2026-01-02       94869  CERAVE LOTIUNE HIDRATANTA PENTRU FATA SI CORP ...
# 731 2026-01-03       94869  CERAVE LOTIUNE HIDRATANTA PENTRU FATA SI CORP ...
# 732 2026-01-04       94869  CERAVE LOTIUNE HIDRATANTA PENTRU FATA SI CORP ...
#
#      CANTITATE  VAL_IESIRE_FARA_TVA  VAL_INTRARE_FARA_TVA  TOTAL_DISCOUNT  \
# 0            0                 0.00                  0.00             0.0
# 1            0                 0.00                  0.00             0.0
# 2           10               571.46                508.30             0.0
# 3            4               228.57                203.32             0.0
# 4           12               685.69                609.96             0.0
# ..         ...                  ...                   ...             ...
# 728          1                61.99                 54.15             0.0
# 729          0                 0.00                  0.00             0.0
# 730          0                 0.00                  0.00             0.0
# 731          6               371.88                324.90             0.0
# 732          6               371.91                324.90             0.0
#
#      ADAOS  STOC_INITIAL  DOW  ESTE_WEEKEND  ZI_DIN_LUNA
# 0     0.00           168    0             0            1
# 1     0.00           168    1             0            2
# 2    63.16           168    2             0            3
# 3    25.25           158    3             0            4
# 4    75.73           214    4             0            5
# ..     ...           ...  ...           ...          ...
# 728   7.84           243    2             0           31
# 729   0.00           242    3             0            1
# 730   0.00           242    4             0            2
# 731  46.98           242    5             1            3
# 732  47.01           236    6             1            4
#
# [733 rows x 12 columns]

# %%
fig = px.line(df, x='DATA', y='CANTITATE', title='Time Series with Range Slider and Selectors')

fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1m", step="month", stepmode="backward"),
            dict(count=6, label="6m", step="month", stepmode="backward"),
            # dict(count=1, label="YTD", step="year", stepmode="todate"),
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(step="all")
        ])
    )
)

fig.update_layout(width=1100, height=500)
fig.show()

# %% [markdown]
# ## ARIMA

# %%
# df_art = df.set_index("DATA")["CANTITATE"].asfreq("D")
# ARIMA works with series, not dataframes
df_art = (
    df
    .set_index("DATA")["CANTITATE"]
    .astype(float)
    .sort_index()
)

# %%
df_art
# Out:
# DATA
# 2024-01-01     0.0
# 2024-01-02     0.0
# 2024-01-03    10.0
# 2024-01-04     4.0
# 2024-01-05    12.0
#               ...
# 2025-12-31     1.0
# 2026-01-01     0.0
# 2026-01-02     0.0
# 2026-01-03     6.0
# 2026-01-04     6.0
# Name: CANTITATE, Length: 733, dtype: float64

# %%
df_art.map(type).value_counts().head(10)
# Out:
# CANTITATE
# <class 'float'>    733
# Name: count, dtype: int64

# %%
type(df_art)
df_art.name
df_art.index.name
df_art.dtype
df_art.head()
# Out:
# DATA
# 2024-01-01     0.0
# 2024-01-02     0.0
# 2024-01-03    10.0
# 2024-01-04     4.0
# 2024-01-05    12.0
# Name: CANTITATE, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
# Out:
# C:\Users\Mara\AppData\Roaming\Python\Python313\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning:
#
# In the future `np.object` will be defined as the corresponding NumPy scalar.

# %%
# pip install tensorflow

# %%
split_ratio = 0.8
n = len(df_art)
split_idx = int(n * split_ratio)

split_idx
# Out:
# 586

# %%
train = df_art.iloc[:split_idx]
test  = df_art.iloc[split_idx:]

# %%
# import libraries
from statsmodels.tsa.stattools import adfuller

# ADF test
result = adfuller(train.dropna())
print('ADF Statistic:', result[0])
print('p-value:', result[1])

# if p-value > 0.05, the series is non-stationary and needs differencing
if result[1] > 0.05:
    print("needs differencing")
else:
    print("time series is stationary")
# Out:
# ADF Statistic: -4.243044051430304
# p-value: 0.0005566642641443016
# time series is stationary

# %%
from pmdarima import auto_arima

model_auto = auto_arima(
    train,
    seasonal=False,
    d=0,
    stepwise=True,
    suppress_warnings=True,
    trace=True
)

model_auto.order
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=3166.313, Time=0.22 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=4188.339, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=3321.500, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=3768.901, Time=0.04 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=3168.610, Time=0.15 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=3172.274, Time=0.15 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=3167.222, Time=0.21 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=3166.923, Time=0.29 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=3179.886, Time=0.07 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=3165.103, Time=0.16 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=3531.179, Time=0.10 sec
#  ARIMA(1,0,4)(0,0,0)[0]             : AIC=3167.014, Time=0.19 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=3622.858, Time=0.08 sec
#  ARIMA(0,0,4)(0,0,0)[0]             : AIC=3451.241, Time=0.14 sec
#  ARIMA(2,0,4)(0,0,0)[0]             : AIC=3168.779, Time=0.36 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=3152.712, Time=0.23 sec
#  ARIMA(0,0,3)(0,0,0)[0] intercept   : AIC=3233.847, Time=0.15 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=3157.638, Time=0.18 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=3152.891, Time=0.53 sec
#  ARIMA(1,0,4)(0,0,0)[0] intercept   : AIC=3154.179, Time=0.27 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=3265.002, Time=0.10 sec
#  ARIMA(0,0,4)(0,0,0)[0] intercept   : AIC=3216.706, Time=0.20 sec
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=3154.865, Time=0.23 sec
#  ARIMA(2,0,4)(0,0,0)[0] intercept   : AIC=3151.952, Time=0.89 sec
#  ARIMA(3,0,4)(0,0,0)[0] intercept   : AIC=3143.261, Time=1.03 sec
#  ARIMA(3,0,3)(0,0,0)[0] intercept   : AIC=3151.987, Time=0.73 sec
#  ARIMA(4,0,4)(0,0,0)[0] intercept   : AIC=3144.810, Time=1.00 sec
#  ARIMA(3,0,5)(0,0,0)[0] intercept   : AIC=3153.784, Time=0.96 sec
#  ARIMA(2,0,5)(0,0,0)[0] intercept   : AIC=3154.260, Time=0.93 sec
#  ARIMA(4,0,3)(0,0,0)[0] intercept   : AIC=3155.969, Time=0.80 sec
#  ARIMA(4,0,5)(0,0,0)[0] intercept   : AIC=3151.729, Time=0.99 sec
#  ARIMA(3,0,4)(0,0,0)[0]             : AIC=3158.560, Time=0.77 sec
#
# Best model:  ARIMA(3,0,4)(0,0,0)[0] intercept
# Total fit time: 12.177 seconds
# (3, 0, 4)

# %%
from statsmodels.tsa.arima.model import ARIMA

arima = ARIMA(train, order=(5, 0, 4))
arima_fit = arima.fit()
# Out:
# C:\Users\Mara\AppData\Roaming\Python\Python313\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# C:\Users\Mara\AppData\Roaming\Python\Python313\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# C:\Users\Mara\AppData\Roaming\Python\Python313\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.

# %%
pred_arima = arima_fit.forecast(steps=len(test))

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

mae = mean_absolute_error(test, pred_arima)

mse = mean_squared_error(test, pred_arima)
rmse = np.sqrt(mse)

r2 = r2_score(test, pred_arima)


mae = float(mae)
rmse = float(rmse)


mae, rmse, r2

# %%
import numpy as np

r = np.corrcoef(test, pred_arima)[0, 1]
float(r)
# arata daca modelul urmareste trandul, nu cat de exact prezice

# %%
import pandas as pd
import plotly.express as px

df_plot_arima = pd.DataFrame({
    "DATA": test.index,
    "Actual": test.values,
    "Predicted": pred_arima
})

df_long_arima = df_plot_arima.melt(
    id_vars="DATA",
    value_vars=["Actual", "Predicted"],
    var_name="Serie",
    value_name="Cantitate"
)

fig = px.line(
    df_long_arima,
    x="DATA",
    y="Cantitate",
    color="Serie",
    title="ARIMA – Actual vs Predicted"
)

fig.update_layout(
    xaxis_title="Data",
    yaxis_title="Cantitate vândută",
    hovermode="x unified",
    legend_title_text=""
)

fig.update_xaxes(rangeslider_visible=True)

fig.show()
